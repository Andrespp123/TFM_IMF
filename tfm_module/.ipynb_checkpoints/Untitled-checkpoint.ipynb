# %%
import json
import pandas as pd

data_file = open("yelp_academic_dataset_review.json")
data = []

for i in range(2000):
    line = data_file.readline()
    if not line:
        break
    data.append(json.loads(line))

data_file.close()

review_df = pd.DataFrame(data)
review_df.head()
# Out:
#                                                0
# 0  {'stars': 3.0, 'text': 'If you decide to eat h...  \
#
#                                                1
# 0  {'stars': 5.0, 'text': 'I've taken a lot of sp...  \
#
#                                                2
# 0  {'stars': 3.0, 'text': 'Family diner. Had the ...  \
#
#                                                3
# 0  {'stars': 5.0, 'text': 'Wow!  Yummy, different...  \
#
#                                                4
# 0  {'stars': 4.0, 'text': 'Cute interior and owne...  \
#
#                                                5
# 0  {'stars': 1.0, 'text': 'I am a long term frequ...  \
#
#                                                6
# 0  {'stars': 5.0, 'text': 'Loved this tour! I gra...  \
#
#                                                7
# 0  {'stars': 5.0, 'text': 'Amazingly amazing wing...  \
#
#                                                8
# 0  {'stars': 3.0, 'text': 'This easter instead of...  \
#
#                                                9      ...
# 0  {'stars': 3.0, 'text': 'Had a party of 6 here ...  ...  \
#
#                                                99990
# 0  {'stars': 3.0, 'text': 'It's tough to review t...  \
#
#                                                99991
# 0  {'stars': 1.0, 'text': 'Not hygienic and Fresh...  \
#
#                                                99992
# 0  {'stars': 4.0, 'text': 'Less greasy than 5 Guy...  \
#
#                                                99993
# 0  {'stars': 4.0, 'text': 'We liked everything ab...  \
#
#                                                99994
# 0  {'stars': 2.0, 'text': 'I had a late lunch wit...  \
#
#                                                99995
# 0  {'stars': 4.0, 'text': 'Came here for lunch wi...  \
#
#                                                99996
# 0  {'stars': 1.0, 'text': 'The equipment is so ol...  \
#
#                                                99997
# 0  {'stars': 4.0, 'text': 'This is one of my favo...  \
#
#                                                99998
# 0  {'stars': 2.0, 'text': 'Came here for brunch -...  \
#
#                                                99999
# 0  {'stars': 5.0, 'text': 'Came in for my 5-6 mon...
#
# [1 rows x 100000 columns]

# %%
# Nos quedamos solo con las reseñas que marcan 1 o 5 estrellas para conseguir mejores resultados en el entrenamiento.
review_df = review_df[(review_df['stars'] == 1) | (review_df['stars'] == 5)]

# Se reemplazan los valores en la columna stars de 1 a 0 y 5 a 1 para entrenar el modelo
review_df['liked'] = review_df['stars'].replace({1:0, 5:1})

# Filtramos solo para quedarnos solo con el texto de la reseña y la estrella
review_df = review_df[['text', 'liked']]

print("Reviews for training:",len(review_df))
review_df.head()
